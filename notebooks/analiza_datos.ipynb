# %%
import pandas as pd   
#__________________________

# Reemplaza 'archivo.csv' con el nombre o la ruta de tu archivo CSV
ruta_archivo = r"C:\Temp\PUB_EMPRESAS_AGRUPADO.CSV"
df = pd.read_csv(ruta_archivo, encoding='utf-8')  # Usa encoding='latin1' si tienes caracteres especiales

# Verifica las primeras filas
print(df.head())

# %%
# Diccionario de renombre limpio
df_agrupado = df.rename(columns={
    'RUT': 'rut',
    'DV_first': 'dv_first',
    'Razón social_first': 'razon_social_first',
    'Fecha inicio de actividades vige_first': 'fecha_inicio_de_actividades_first',
    'Fecha término de giro_first': 'fecha_termino_de_giro_first',
    'Fecha primera inscripción de ac_first': 'fecha_primera_inscripcion_first',
    'Tipo término de giro_first': 'tipo_termino_de_giro_first',
    'Tipo de contribuyente_first': 'tipo_de_contribuyente_first',
    'Subtipo de contribuyente_first': 'subtipo_de_contribuyente_first',
    'Rubro económico_first': 'rubro_economico_first',
    'Subrubro económico_first': 'subrubro_economico_first',
    'Actividad económica_first': 'actividad_economica_first',
    'Región_first': 'region_first',
    'Provincia_first': 'provincia_first',
    'Comuna_first': 'comuna_first',
    'R_PRESUNTA_first': 'r_presunta_first',
    'OTROS_REGIMENES_first': 'otros_regimenes_first',
    'Anno_min': 'anno_min',
    'Anno_max': 'anno_max',
    'Trabajadores_min': 'trabajadores_min',
    'Trabajadores_max': 'trabajadores_max',
    'Ventas_min': 'ventas_min',
    'Ventas_max': 'ventas_max',
    'Tramo_capital_propio_positivo_min': 'tramo_capital_propio_positivo_min',
    'Tramo_capital_propio_positivo_max': 'tramo_capital_propio_positivo_max',
    'Tramo_capital_propio_negativo_min': 'tramo_capital_propio_negativo_min',
    'Tramo_capital_propio_negativo_max': 'tramo_capital_propio_negativo_max',
    'Numero_de_annos': 'numero_de_annos',
    'Termino_Giro': 'termino_giro'
})

# %%
df_agrupado.info
# Out:
# <bound method DataFrame.info of               rut dv_first                      razon_social_first  \
# 0        47003012        7             TACONIC  OPPORTUITY FUND LP
# 1        47003030        5                 CAPLIMIT INVESTMENTS BV
# 2        47003194        8          RUT CUSTODIO LARRAIN VIAL S A.
# 3        47003969        8          RUT CUSTODIO LARRAIN VIAL S A.
# 4        47012566        7        BBVA CORREDORA DE BOLSA LIMITADA
# ...           ...      ...                                     ...
# 1558275  99599800        9                  AUTOMOTRIZ P.G CAR S.A
# 1558276  99599810        6  COMPANIA DE TRANSPORTES INTEGRADOS S A
# 1558277  99599830        0   INMOBILIARIA E INVERSIONES PUCARA S A
# 1558278  99599850        5                SOLUCIONES ABIERTAS  S A
# 1558279  99599860        2                                ORAND SA
#
#         fecha_inicio_de_actividades_first fecha_termino_de_giro_first  \
# ...
